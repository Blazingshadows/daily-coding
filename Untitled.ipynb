# %%
name = "Aditya"

# %%
name
# Out:
# 'Aditya'

# %%
name.upper()
# Out:
# 'ADITYA'

# %%
name
# Out:
# 'Aditya'

# %%
name.endswith("tya")
# Out:
# True

# %%
name.count("a" or "A")
# Out:
# 1

# %%
name.lower().count("a")
# Out:
# 2

# %%
name = "hi \nADI"

# %%
name.strip()
# Out:
# 'hi \nADI'

# %%
print(name)
# Out:
# hi
# ADI

# %%
print(name.strip())
# Out:
# hi
# ADI

# %%
"\n hello \n world \n ".strip()
# Out:
# 'hello \n world'

# %%
print(len(name))
# Out:
# 7

# %%
"2025.12.26".replace(".", "/")
# Out:
# '2025/12/26'

# %%
courses = "ai,ml,dl,cv"

# %%
courses.split(",")
# Out:
# ['ai', 'ml', 'dl', 'cv']

# %%
courses
# Out:
# 'ai,ml,dl,cv'

# %%
",".join(["ai","ml","dl","cv"])
# Out:
# 'ai,ml,dl,cv'

# %%
s = "Manipal University Jaipur"

# %%
print(len(s))
# Out:
# 25

# %%
lst1 = s.split(" ")

# %%
lst1
# Out:
# ['Manipal', 'University', 'Jaipur']

# %%
lst1[0]
# Out:
# 'Manipal'

# %%
lst1[0][0]
# Out:
# 'M'

# %%
s.strip()
# Out:
# 'Manipal University Jaipur'

# %%
s = s.lower()

# %%
s.count("i")
# Out:
# 4

# %%
s[0:8]
# Out:
# 'manipal '

# %%
s[0:8].strip()
# Out:
# 'manipal'

# %%
data = [{"name":"A","scores" :[80,90,85]},
        {"name":"B","scores" :[70,60]},
         {"name":"C","scores" :[]}]

# %%
data
# Out:
# [{'name': 'A', 'scores': [80, 90, 85]},
#  {'name': 'B', 'scores': [70, 60]},
#  {'name': 'C', 'scores': []}]

# %%
data[0]
# Out:
# {'name': 'A', 'scores': [80, 90, 85]}

# %%
data[0].values()
# Out:
# dict_values(['A', [80, 90, 85]])

# %%
for x in data
