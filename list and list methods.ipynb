# %%
l  = [3,4,5,23]

# %%
l
# Out:
# [3, 4, 5, 23]

# %%
l[0] = 11

# %%
l
# Out:
# [11, 4, 5, 23]

# %%
l.append(10)

# %%
l2 = [1,3,6]
l.extend(l2)

# %%
l
# Out:
# [11, 4, 5, 23, 10, 1, 3, 6]

# %%
l.insert(100,"start")

# %%
l
# Out:
# [11, 4, 5, 23, 10, 1, 3, 6, 'start']

# %%
l.remove("start")

# %%
l
# Out:
# [11, 4, 5, 23, 10, 1, 3, 6]

# %%
last = l.pop()

# %%
last
# Out:
# 6

# %%
l
# Out:
# [11, 4, 5, 23, 10, 1, 3]

# %%
l.clear()

# %%
l
# Out:
# []

# %%
l2
# Out:
# [1, 3, 6]

# %%
l2.index(3)
# Out:
# 1

# %%
l2.extend([10,23,35,67,99,8,32])

# %%
l2
# Out:
# [1, 3, 6, 10, 23, 35, 67, 99, 8, 32]

# %%
l2.count(32)
# Out:
# 1

# %% [markdown]
# l2.

# %%
l2.sort(key = None)

# %%
l2
# Out:
# [1, 3, 6, 8, 10, 23, 32, 35, 67, 99]
